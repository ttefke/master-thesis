# %%
# Import utility to capture data
import subprocess

# %%
# Set bounds
MIN = 0
MAX = 250

# %%
# Capture
"""
for i in range(MIN+1, MAX+1):
    result = subprocess.run("./scdrand", capture_output=True)
    bits = result.stdout.decode("ascii")
    with open(f"data/nitrokey/{i:03d}", "w") as f:
        f.write(bits)
"""
# Out:
# '\nfor i in range(MIN+1, MAX+1):\n    result = subprocess.run("./scdrand", capture_output=True)\n    bits = result.stdout.decode("ascii")\n    with open(f"data/nitrokey/{i:03d}", "w") as f:\n        f.write(bits)\n'

# %%
# Evaluate
# DONE
#for i in range(MIN+1, MAX+1):
    #subprocess.run(["cargo", "run", "evaluate", f"--path=data/nitrokey/{i:03d}", f"--out-path=data/nitrokey/{i:03d}-results.json"])

# %%
# Evaluate files
import json

contents = []

for i in range(1, MAX+1):
    file = f"data/nitrokey/{i:03d}-results.json"

    with open(file, "r") as f:
        content = json.load(f)
        
    contents.append(content)

# %%
# Combine results
results = dict()

# Create keys
for key in ["monobit_frequency", "block_frequency", "runs", "longest_run",
            "binary_rank", "dft", "non_overlapping", "overlapping", "universal",
            "linear_complexity", "serial", "approximate_entropy", "cusum",
            "random_excursions", "random_excursions_variant", #"universal_cn", "universal_t", "universal_t_cn"
            ]:
    results[key] = []

# %%
for content in contents:
    for key, value in content.items():
        match key:
            case "monobit_frequency" | "block_frequency" \
                | "runs" | "longest_run" | \
                "binary_rank" | "dft" \
                | "linear_complexity" | "approximate_entropy":
                results[key].append(value)
            case "non_overlapping" | "serial" | "cusum" \
                | "overlapping" | "random_excursions" | "random_excursions_variant":
                results[key].extend(value)
            case "universal":
                results[key].append(value[0])
                #results["universal_cn"].append(value[1])
                #results["universal_t"].append(value[2])
                #results["universal_t_cn"].append(value[3])

# %%
import matplotlib.pyplot as plt

descriptions = {
    "monobit_frequency": "Frequency (monobit) test",
    "block_frequency": "Frequency test with a block",
    "runs": "Runs test",
    "longest_run": "Test for the longest run of ones in a block",
    "binary_rank": "Binary matrix rank test",
    "dft": "Discrete fourier transform (spectral) test",
    "non_overlapping": "Non-overlapping template matching test",
    "overlapping": "Overlapping template matching test",
    "universal": "Maurer's universal test",
    "universal_cn": "Maurer's universal test (CN approx.)",
    "universal_t": "Maurer's universal test (t-test)",
    "universal_t_cn": "Maurer's universal test (CN approx.; t-test)",
    "linear_complexity": "Linear complexity test",
    "serial": "Serial test",
    "approximate_entropy": "Approximate entropy test",
    "cusum": "Cumulative sums (cusum) test",
    "random_excursions": "Random excursions test",
    "random_excursions_variant": "Random excursions variant test"
}
"""
for key in results.keys():
    fig, ax = plt.subplots()
    ax.hist(results[key], bins=10, edgecolor="white")
    ax.set_title(descriptions[key])
    plt.savefig(f"./figures/nitrokey/{key}.pdf")
"""
font = {"size": 8}
plt.rc("font", **font)

fig, axs = plt.subplots(5, 3, figsize=(10, 15), constrained_layout=True)
i = 0
for key in results.keys():
    row = i % 3
    column = int(i/3)
    axs[column, row].hist(results[key], bins=10, edgecolor="white", color="black")
    axs[column, row].set_title(descriptions[key])
    i += 1
    
plt.savefig(f"./figures/nitrokey.pdf")

# %%
# Compute proportions
# MAX = sample size
alpha = 0.01
p = 1- alpha
confidence_min = p - 3 * (((p*(1-p))/MAX) ** 0.5)
confidence_max = p + 3 * (((p*(1-p))/MAX) ** 0.5)
print(f"min. confidence: {confidence_min:.4f}, max. confidence: {confidence_max:.4f}")
# Out:
# min. confidence: 0.9711, max. confidence: 1.0089

# %%
import numpy as np

# Table header
print("""\\begin{table}[htb]
\t\\centering
\t\\caption{Proportion of sequences passing a test - Nitrokey}
\t\\label{tab:nitrokey-proportions}
\t\\begin{tabular}{|p{7cm}|p{2.1cm}|c|c|}
\t\t\\hline
\t\tTest    &   Accepted observations   &   Proportion &   Result\\\\
\t\t\\hline""")

for key, value in results.items():
    print(f"\t\t{descriptions[key]}", end=" & ")
    
    # Compute proportion
    observations = np.array(value)
    accepted_p_values = (observations >= alpha).sum()
    proportion = accepted_p_values / len(observations)
    print(f"{accepted_p_values}/{len(observations)}", end=" & ")
    print(f"{proportion:.4f}", end=" & ")
    
    if confidence_min <= proportion <= confidence_max:
        print("accepted", end="\\\\\n")
    else:
        print("\\textbf{rejected}", end="\\\\\n")
        
    print("\t\t\\hline")
    
# Table footer
print("""\t\\end{tabular}
\\end{table}""")
# Out:
# \begin{table}[htb]
# 	\centering
# 	\caption{Proportion of sequences passing a test - Nitrokey}
# 	\label{tab:nitrokey-proportions}
# 	\begin{tabular}{|p{7cm}|p{2.1cm}|c|c|}
# 		\hline
# 		Test    &   Accepted observations   &   Proportion &   Result\\
# 		\hline
# 		Frequency (monobit) test & 248/250 & 0.9920 & accepted\\
# 		\hline
# 		Frequency test with a block & 250/250 & 1.0000 & accepted\\
# 		\hline
# 		Runs test & 239/250 & 0.9560 & \textbf{rejected}\\
# 		\hline
# 		Test for the longest run of ones in a block & 248/250 & 0.9920 & accepted\\
# 		\hline
# 		Binary matrix rank test & 250/250 & 1.0000 & accepted\\
# 		\hline
# 		Discrete fourier transform (spectral) test & 247/250 & 0.9880 & accepted\\
# 		\hline
# 		Non-overlapping template matching test & 36643/37000 & 0.9904 & accepted\\
# 		\hline
# 		Overlapping template matching test & 498/500 & 0.9960 & accepted\\
# 		\hline
# 		Maurer's universal test & 247/250 & 0.9880 & accepted\\
# 		\hline
# 		Linear complexity test & 248/250 & 0.9920 & accepted\\
# 		\hline
# 		Serial test & 498/500 & 0.9960 & accepted\\
# 		\hline
# 		Approximate entropy test & 248/250 & 0.9920 & accepted\\
# 		\hline
# 		Cumulative sums (cusum) test & 496/500 & 0.9920 & accepted\\
# 		\hline
# 		Random excursions test & 1211/2000 & 0.6055 & \textbf{rejected}\\
# 		\hline
# 		Random excursions variant test & 2740/4500 & 0.6089 & \textbf{rejected}\\
# 		\hline
# 	\end{tabular}
# \end{table}

# %%
import scipy

# Table header
print("""\\begin{table}[htb]
\t\\centering
\t\\caption{Uniform distribution of p-values - Nitrokey}
\t\\label{tab:nitrokey-uniform}
\t\\begin{tabular}{|p{7cm}|p{2.1cm}|c|c|}
\t\t\\hline
\t\tTest    &   $\\chi^2$-value   &   p-value &   Result\\\\
\t\t\\hline""")

# Perform goodness-of-fit X^2-test
for key, value in results.items():
    print(f"\t\t{descriptions[key]}", end=" & ")
    
    chi2 = 0.0
    observations = np.array(value)
    expected = len(value) / 10
    
    for i in range(10):
        # Range of accepted items
        min_ = i / 10
        max_ = min_ + 0.1
        accepted_number_p_values = ((observations >= min_) & (observations < max_)).sum()
        chi2 += (accepted_number_p_values - expected) ** 2
    
    # Compute chi-square
    chi2 /= expected
    print(f"{chi2:.4f}", end=" & ")
    pvalue = scipy.special.gammaincc(4.5, chi2/2)
    print(f"{pvalue:.4f}", end=" & ")
    
    if pvalue >= 0.0001:
        print("accepted", end="\\\\\n")
    else:
        print("\\textbf{rejected}", end="\\\\\n")
    print("\t\t\\hline")
    
# Table footer
print("""\t\\end{tabular}
\\end{table}""")
# Out:
# \begin{table}[htb]
# 	\centering
# 	\caption{Uniform distribution of p-values - Nitrokey}
# 	\label{tab:nitrokey-uniform}
# 	\begin{tabular}{|p{7cm}|p{2.1cm}|c|c|}
# 		\hline
# 		Test    &   $\chi^2$-value   &   p-value &   Result\\
# 		\hline
# 		Frequency (monobit) test & 5.5200 & 0.7868 & accepted\\
# 		\hline
# 		Frequency test with a block & 5.2800 & 0.8092 & accepted\\
# 		\hline
# 		Runs test & 37.1200 & 0.0000 & \textbf{rejected}\\
# 		\hline
# 		Test for the longest run of ones in a block & 11.5200 & 0.2417 & accepted\\
# 		\hline
# 		Binary matrix rank test & 6.0000 & 0.7399 & accepted\\
# 		\hline
# 		Discrete fourier transform (spectral) test & 3.9600 & 0.9140 & accepted\\
# 		\hline
# 		Non-overlapping template matching test & 9.9319 & 0.3560 & accepted\\
# 		\hline
# 		Overlapping template matching test & 7.6400 & 0.5708 & accepted\\
# 		\hline
# 		Maurer's universal test & 7.9200 & 0.5422 & accepted\\
# 		\hline
# 		Linear complexity test & 4.8000 & 0.8514 & accepted\\
# 		\hline
# 		Serial test & 10.0800 & 0.3440 & accepted\\
# 		\hline
# 		Approximate entropy test & 8.4000 & 0.4944 & accepted\\
# 		\hline
# 		Cumulative sums (cusum) test & 8.0800 & 0.5261 & accepted\\
# 		\hline
# 		Random excursions test & 2678.3900 & 0.0000 & \textbf{rejected}\\
# 		\hline
# 		Random excursions variant test & 6138.0956 & 0.0000 & \textbf{rejected}\\
# 		\hline
# 	\end{tabular}
# \end{table}
