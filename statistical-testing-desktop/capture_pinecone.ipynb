# %%
# Import utility to capture data
import subprocess

# %%
# Set bounds
MIN = 0
MAX = 250

# %%
# Capture
# DONE
#for i in range(MIN+1, MAX+1):
#    subprocess.run(["cargo", "run", "capture", f"--path=data/pinecone/{i:03d}"])

# %%
# Evaluate
# DONE
#for i in range(MIN+1, MAX+1):
#    subprocess.run(["cargo", "run", "evaluate", f"--path=data/pinecone/{i:03d}", f"--out-path=data/pinecone/{i:03d}-results.json"])

# %%
# Evaluate files
import json

contents = []

for i in range(1, MAX+1):
    file = f"data/pinecone/{i:03d}-results.json"

    with open(file, "r") as f:
        content = json.load(f)
        
    contents.append(content)

# %%
# Combine results
results = dict()

# Create keys
for key in ["monobit_frequency", "block_frequency", "runs", "longest_run",
            "binary_rank", "dft", "non_overlapping", "overlapping", "universal",
            "linear_complexity", "serial", "approximate_entropy", "cusum",
            "random_excursions", "random_excursions_variant", #"universal_cn", "universal_t", "universal_t_cn"
            ]:
    results[key] = []

# %%
for content in contents:
    for key, value in content.items():
        match key:
            case "monobit_frequency" | "block_frequency" \
                | "runs" | "longest_run" | \
                "binary_rank" | "dft" \
                | "linear_complexity" | "approximate_entropy":
                results[key].append(value)
            case "non_overlapping" | "serial" | "cusum" \
                | "overlapping" | "random_excursions" | "random_excursions_variant":
                results[key].extend(value)
            case "universal":
                results[key].append(value[0])
                #results["universal_cn"].append(value[1])
                #results["universal_t"].append(value[2])
                #results["universal_t_cn"].append(value[3])

# %%
import matplotlib.pyplot as plt

descriptions = {
    "monobit_frequency": "Frequency (monobit) test",
    "block_frequency": "Frequency test with a block",
    "runs": "Runs test",
    "longest_run": "Test for the longest run of ones in a block",
    "binary_rank": "Binary matrix rank test",
    "dft": "Discrete fourier transform (spectral) test",
    "non_overlapping": "Non-overlapping template matching test",
    "overlapping": "Overlapping template matching test",
    "universal": "Maurer's universal test",
    "universal_cn": "Maurer's universal test (CN approx.)",
    "universal_t": "Maurer's universal test (t-test)",
    "universal_t_cn": "Maurer's universal test (CN approx.; t-test)",
    "linear_complexity": "Linear complexity test",
    "serial": "Serial test",
    "approximate_entropy": "Approximate entropy test",
    "cusum": "Cumulative sums (cusum) test",
    "random_excursions": "Random excursions test",
    "random_excursions_variant": "Random excursions variant test"
}
"""
for key in results.keys():
    fig, ax = plt.subplots()
    ax.hist(results[key], bins=10, edgecolor="white")
    ax.set_title(descriptions[key])
    plt.savefig(f"./figures/pinecone/{key}.pdf")
"""

font = {"size": 8}
plt.rc("font", **font)

fig, axs = plt.subplots(5, 3, figsize=(10, 15), constrained_layout=True) # 6, 3
i = 0
for key in results.keys():
    row = i % 3
    column = int(i/3)
    axs[column, row].hist(results[key], bins=10, edgecolor="white", color="black")
    axs[column, row].set_title(descriptions[key])
    i += 1
    
plt.savefig(f"./figures/pinecone.pdf")

# %%
import matplotlib.pyplot as plt

descriptions = {
    "monobit_frequency": "Frequency (monobit) test",
    "block_frequency": "Frequency test with a block",
    "runs": "Runs test",
    "longest_run": "Test for the longest run of ones in a block",
    "binary_rank": "Binary matrix rank test",
    "dft": "Discrete fourier transform (spectral) test",
    "non_overlapping": "Non-overlapping template matching test",
    "overlapping": "Overlapping template matching test",
    "universal": "Maurer's universal test",
    "universal_cn": "Maurer's universal test (CN approx.)",
    "universal_t": "Maurer's universal test (t-test)",
    "universal_t_cn": "Maurer's universal test (CN approx.; t-test)",
    "linear_complexity": "Linear complexity test",
    "serial": "Serial test",
    "approximate_entropy": "Approximate entropy test",
    "cusum": "Cumulative sums (cusum) test",
    "random_excursions": "Random excursions test",
    "random_excursions_variant": "Random excursions variant test"
}

font = {"size": 8}
plt.rc("font", **font)

fig, axs = plt.subplots(3, 5, figsize=(16, 12), constrained_layout=True)
i = 0
for key in results.keys():
    #if key in ["universal_cn", "universal_t", "universal_t_cn"]:
    #    continue
    row = i % 5
    column = int(i/5)
    axs[column, row].hist(results[key], bins=10, edgecolor="white", color="black")
    axs[column, row].set_title(descriptions[key])
    i += 1
    
plt.savefig(f"./figures/pinecone_presentation.pdf")

# %%
# Compute proportions
# MAX = sample size
alpha = 0.01
p = 1- alpha
confidence_min = p - 3 * (((p*(1-p))/MAX) ** 0.5)
confidence_max = p + 3 * (((p*(1-p))/MAX) ** 0.5)
print(f"min. confidence: {confidence_min:.4f}, max. confidence: {confidence_max:.4f}")
# Out:
# min. confidence: 0.9711, max. confidence: 1.0089

# %%
import numpy as np

# Table header
print("""\\begin{table}[htb]
\t\\centering
\t\\caption{Proportion of sequences passing a test - PineCone}
\t\\label{tab:pc-proportions}
\t\\begin{tabular}{|p{7cm}|p{2.1cm}|c|c|}
\t\t\\hline
\t\tTest    &   Accepted observations   &   Proportion &   Result\\\\
\t\t\\hline""")

for key, value in results.items():
    print(f"\t\t{descriptions[key]}", end=" & ")
    
    # Compute proportion
    observations = np.array(value)
    accepted_p_values = (observations >= alpha).sum()
    proportion = accepted_p_values / len(observations)
    print(f"{accepted_p_values}/{len(observations)}", end=" & ")
    print(f"{proportion:.4f}", end=" & ")
    
    if confidence_min <= proportion <= confidence_max:
        print("accepted", end="\\\\\n")
    else:
        print("\\textbf{rejected}", end="\\\\\n")
        
    print("\t\t\\hline")
    
# Table footer
print("""\t\\end{tabular}
\\end{table}""")
# Out:
# \begin{table}[htb]
# 	\centering
# 	\caption{Proportion of sequences passing a test - PineCone}
# 	\label{tab:pc-proportions}
# 	\begin{tabular}{|p{7cm}|p{2.1cm}|c|c|}
# 		\hline
# 		Test    &   Accepted observations   &   Proportion &   Result\\
# 		\hline
# 		Frequency (monobit) test & 245/250 & 0.9800 & accepted\\
# 		\hline
# 		Frequency test with a block & 249/250 & 0.9960 & accepted\\
# 		\hline
# 		Runs test & 249/250 & 0.9960 & accepted\\
# 		\hline
# 		Test for the longest run of ones in a block & 248/250 & 0.9920 & accepted\\
# 		\hline
# 		Binary matrix rank test & 250/250 & 1.0000 & accepted\\
# 		\hline
# 		Discrete fourier transform (spectral) test & 249/250 & 0.9960 & accepted\\
# 		\hline
# 		Non-overlapping template matching test & 36641/37000 & 0.9903 & accepted\\
# 		\hline
# 		Overlapping template matching test & 493/500 & 0.9860 & accepted\\
# 		\hline
# 		Maurer's universal test & 247/250 & 0.9880 & accepted\\
# 		\hline
# 		Linear complexity test & 242/250 & 0.9680 & \textbf{rejected}\\
# 		\hline
# 		Serial test & 497/500 & 0.9940 & accepted\\
# 		\hline
# 		Approximate entropy test & 248/250 & 0.9920 & accepted\\
# 		\hline
# 		Cumulative sums (cusum) test & 490/500 & 0.9800 & accepted\\
# 		\hline
# 		Random excursions test & 1227/2000 & 0.6135 & \textbf{rejected}\\
# 		\hline
# 		Random excursions variant test & 2771/4500 & 0.6158 & \textbf{rejected}\\
# 		\hline
# 	\end{tabular}
# \end{table}

# %%
import scipy

# Table header
print("""\\begin{table}[htb]
\t\\centering
\t\\caption{Uniform distribution of p-values - PineCone}
\t\\label{tab:pc-uniform}
\t\\begin{tabular}{|p{7cm}|p{2.1cm}|c|c|}
\t\t\\hline
\t\tTest    &   $\\chi^2$-value   &   p-value &   Result\\\\
\t\t\\hline""")

# Perform goodness-of-fit X^2-test
for key, value in results.items():
    print(f"\t\t{descriptions[key]}", end=" & ")
    
    chi2 = 0.0
    observations = np.array(value)
    expected = len(value) / 10
    
    for i in range(10):
        # Range of accepted items
        min_ = i / 10
        max_ = min_ + 0.1
        accepted_number_p_values = ((observations >= min_) & (observations < max_)).sum()
        chi2 += (accepted_number_p_values - expected) ** 2
    
    # Compute chi-square
    chi2 /= expected
    print(f"{chi2:.4f}", end=" & ")
    pvalue = scipy.special.gammaincc(4.5, chi2/2)
    print(f"{pvalue:.4f}", end=" & ")
    
    if pvalue >= 0.0001:
        print("accepted", end="\\\\\n")
    else:
        print("\\textbf{rejected}", end="\\\\\n")
    print("\t\t\\hline")
    
# Table footer
print("""\t\\end{tabular}
\\end{table}""")
# Out:
# \begin{table}[htb]
# 	\centering
# 	\caption{Uniform distribution of p-values - PineCone}
# 	\label{tab:pc-uniform}
# 	\begin{tabular}{|p{7cm}|p{2.1cm}|c|c|}
# 		\hline
# 		Test    &   $\chi^2$-value   &   p-value &   Result\\
# 		\hline
# 		Frequency (monobit) test & 4.5600 & 0.8709 & accepted\\
# 		\hline
# 		Frequency test with a block & 7.4400 & 0.5914 & accepted\\
# 		\hline
# 		Runs test & 6.4800 & 0.6911 & accepted\\
# 		\hline
# 		Test for the longest run of ones in a block & 18.0800 & 0.0343 & accepted\\
# 		\hline
# 		Binary matrix rank test & 4.7200 & 0.8580 & accepted\\
# 		\hline
# 		Discrete fourier transform (spectral) test & 3.8000 & 0.9241 & accepted\\
# 		\hline
# 		Non-overlapping template matching test & 6.6589 & 0.6726 & accepted\\
# 		\hline
# 		Overlapping template matching test & 4.2400 & 0.8949 & accepted\\
# 		\hline
# 		Maurer's universal test & 9.6800 & 0.3770 & accepted\\
# 		\hline
# 		Linear complexity test & 10.0800 & 0.3440 & accepted\\
# 		\hline
# 		Serial test & 17.2400 & 0.0451 & accepted\\
# 		\hline
# 		Approximate entropy test & 12.1600 & 0.2044 & accepted\\
# 		\hline
# 		Cumulative sums (cusum) test & 4.2800 & 0.8920 & accepted\\
# 		\hline
# 		Random excursions test & 2494.8100 & 0.0000 & \textbf{rejected}\\
# 		\hline
# 		Random excursions variant test & 5646.4289 & 0.0000 & \textbf{rejected}\\
# 		\hline
# 	\end{tabular}
# \end{table}
